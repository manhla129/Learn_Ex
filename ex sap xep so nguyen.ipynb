# %%
def sapxep(a, b, c):
    max = a if a > b and a > c else b if b > a and b > c else c
    min = a if a < b and a < c else b if b < a and b < c else c
    mid = a if max != a and min != a else b if max != b and min != b else c
    return min,mid,max

print(sapxep(44,-6,5))
# Out:
# (-6, 5, 44)
