# %%
def count_char(text, char):
    count = 0
    text = text.split()
    for i in text:
        if i == char:
            count+=1
    return count

text = 'một hai ba bốn năm sáu một hai ba hai'
char = 'hai'
print(count_char(text, char))
# Out:
# 3
