# %%
def get1st2nd(list_item):
    if len(list_item) < 2:
        return 'Chuỗi không đủ độ dài'
    else:
        list_item.sort()
        return list_item[-1], list_item[-2]
    
print(get1st2nd([2,4,4,5,67,7,3,2]))
# Out:
# (67, 7)
